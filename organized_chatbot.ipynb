# %%
# !pip install langchain openai

# %%
import os
from langchain_openai import ChatOpenAI
from langchain_core.prompts import ChatPromptTemplate
from langchain_core.callbacks import StreamingStdOutCallbackHandler
from dotenv import load_dotenv

# %%
load_dotenv()

API_KEY = os.getenv("OPENAI_API_KEY")

# %%
print("API Key loaded successfully:", bool(API_KEY))
print("API Key:", API_KEY)
# Out:
# API Key loaded successfully: True
# API Key: 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

# %%
No_of_turns = 5
memmory = []

llm = ChatOpenAI(
    model="gpt-4o-mini",
    temperature=0.7,
    streaming=True,
    callbacks=[StreamingStdOutCallbackHandler()]
)

# %%
chat_prompt = ChatPromptTemplate.from_template("""you are a Travel agent chatbot. 
Rules:
- Answer ONLY travel-related queries (flights, hotels, destinations, itineraries, travel tips).
- If the question is NOT travel-related, respond exactly with:
  "I can’t help with it."

conversation History:
{history}
                                               
User: {input}
Agent:""")

summary_prompt = ChatPromptTemplate.from_template("""you are a helpful assistant that summarizes
the conversation history between a user and a travel agent chatbot.
{history}
""")

# %%
user_input = input("\nYou: ")

if user_input.lower() == "exit":
    break

chat(user_input)
# Out:
#   Cell In[9], line 4
#     break
#     ^
# SyntaxError: 'break' outside loop

# %%
def chat_agent():
    global memory
    
    chat_memory = append.memory(user_input)

    history_text = "\n".join(memory)

    chat_chain = chat_prompt | llm

    Response = chat_chain.invoke(
        {"history": history_text, 
         "input": user_input})
    
    if len(memory) > No_of_turns * 2:
        summary_chain = summary_prompt | llm

        summary=summary_chain.invoke({"history": history_text}).content

        chat_memory = [summary]

# %%
def sum
